# %%
import pandas as pd

# %%
df=pd.read_csv("C://Users//ALWAYSRAMESH//Downloads//insurance.csv")

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
model=LabelEncoder()
df['sex']=model.fit_transform(x['sex'])
df['region']=model.fit_transform(x['region'])

# %%
x=df[['age','sex','bmi','children','region','charges']]

# %%
y=df['smoker']

# %%
y
# Out:
# 0       yes
# 1        no
# 2        no
# 3        no
# 4        no
#        ...
# 1333     no
# 1334     no
# 1335     no
# 1336     no
# 1337    yes
# Name: smoker, Length: 1338, dtype: object

# %%
x
# Out:
#       age  sex     bmi  children  region      charges
# 0      19    0  27.900         0       3  16884.92400
# 1      18    1  33.770         1       2   1725.55230
# 2      28    1  33.000         3       2   4449.46200
# 3      33    1  22.705         0       1  21984.47061
# 4      32    1  28.880         0       1   3866.85520
# ...   ...  ...     ...       ...     ...          ...
# 1333   50    1  30.970         3       1  10600.54830
# 1334   18    0  31.920         0       0   2205.98080
# 1335   18    0  36.850         0       2   1629.83350
# 1336   21    0  25.800         0       3   2007.94500
# 1337   61    0  29.070         0       1  29141.36030
#
# [1338 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array(['no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'yes', 'yes',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes',
#        'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'no', 'no', 'no',
#        'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'yes',
#        'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes',
#        'no', 'no', 'no', 'no', 'yes', 'yes', 'no', 'no', 'no', 'no',
#        'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'yes',
#        'no', 'no', 'yes', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no',
#        'no', 'no', 'no', 'no', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no',
#        'yes', 'yes', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no',
#        'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no',
#        'no', 'no', 'no', 'no', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no',
# ...

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
graph=confusion_matrix(y_test,y_pred)
print(graph)
# Out:
# [[306  12]
#  [ 11  73]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.97      0.96      0.96       318
#          yes       0.86      0.87      0.86        84
#
#     accuracy                           0.94       402
#    macro avg       0.91      0.92      0.91       402
# weighted avg       0.94      0.94      0.94       402

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(graph,annot=True)
plt.title('insurance Data')
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier(n_neighbors=1) 
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
prediction = model.predict(x_test)
print("Predicted Class:", prediction)
# Out:
# Predicted Class: ['no' 'no' 'yes' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no'
#  'yes' 'no' 'no' 'no' 'no' 'yes' 'yes' 'no' 'yes' 'yes' 'no' 'no' 'no'
#  'no' 'no' 'no' 'no' 'yes' 'no' 'no' 'no' 'no' 'no' 'yes' 'yes' 'no' 'no'
#  'no' 'yes' 'yes' 'yes' 'no' 'yes' 'no' 'no' 'yes' 'no' 'yes' 'yes' 'yes'
#  'yes' 'no' 'no' 'no' 'no' 'no' 'no' 'yes' 'no' 'no' 'no' 'no' 'yes' 'yes'
#  'no' 'no' 'no' 'no' 'yes' 'no' 'no' 'no' 'no' 'no' 'yes' 'yes' 'no' 'yes'
#  'no' 'no' 'yes' 'no' 'no' 'no' 'no' 'yes' 'no' 'no' 'yes' 'no' 'no' 'no'
#  'yes' 'yes' 'no' 'no' 'no' 'no' 'no' 'yes' 'yes' 'no' 'no' 'no' 'no'
#  'yes' 'no' 'no' 'no' 'yes' 'yes' 'no' 'no' 'no' 'no' 'no' 'yes' 'no' 'no'
#  'no' 'no' 'no' 'yes' 'yes' 'yes' 'no' 'no' 'no' 'no' 'no' 'yes' 'yes'
#  'yes' 'no' 'yes' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no'
#  'no' 'yes' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no'
#  'no' 'yes' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no'
# ...

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.96      0.95      0.96       318
#          yes       0.82      0.86      0.84        84
#
#     accuracy                           0.93       402
#    macro avg       0.89      0.90      0.90       402
# weighted avg       0.93      0.93      0.93       402

# %%
graph=confusion_matrix(y_test,y_pred)
print(graph)
# Out:
# [[302  16]
#  [ 12  72]]

# %%
for i in range(1, 12): 
    model = KNeighborsClassifier(n_neighbors=i)
    model.fit(x_train, y_train)
    
    y_pred = model.predict(x_test)  
    print(f"Model trained with n_neighbors={i}")
    print(classification_report(y_test, y_pred))
# Out:
# Model trained with n_neighbors=1
#               precision    recall  f1-score   support
#
#           no       0.93      0.96      0.95       318
#          yes       0.83      0.74      0.78        84
#
#     accuracy                           0.91       402
#    macro avg       0.88      0.85      0.86       402
# weighted avg       0.91      0.91      0.91       402
#
# Model trained with n_neighbors=2
#               precision    recall  f1-score   support
#
#           no       0.91      0.96      0.93       318
#          yes       0.82      0.63      0.71        84
#
#     accuracy                           0.89       402
#    macro avg       0.86      0.80      0.82       402
# weighted avg       0.89      0.89      0.89       402
#
# Model trained with n_neighbors=3
#               precision    recall  f1-score   support
#
#           no       0.95      0.95      0.95       318
#          yes       0.82      0.80      0.81        84
#
# ...
